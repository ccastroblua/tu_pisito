# %%
from config.configuration import engine
from tools import google_functions as g_func
import pandas as pd

# %%
lat = 40.471342035023184 
lon = -3.6890907774613435
rad = 1000
place = "supermarket"

# %%
data = g_func.get_places(lat, lon, rad, place)

# %%
data
# Out:
# {'html_attributions': [],
#  'next_page_token': 'Aap_uEDClBhl9KwEf7cvLAyC7us4islmHufwNBSCzmx2XMBlHFa5sBFKu8GCLbijlBaZv8_7P8BYhgO-_6ylCNY4y_l8F0EMre9mEKCxPitXi4I3gCtfn9WldaNalH6StDp0OLIgLqZR2Dpii5VofwETlg41G7a3yeR5ZWlryMQs5t-qkESYru5TU_doand2AeEEIRRRCFvDUCGg0douuyxxLOxOoalv3DZ5TiINaZrJYegHH8H1lSUWwoZwkypM9RWbhDqyAvS6caSou5gHDd4Aplycjua5qqjueW0BfVTOCIhVkmN-ob-QVWJ8QkSxE82RPuuvSrJGhn6oUdK5Dc9d89oUrM1hGsBZ6LUG2urw5qKgYrWH7KT3QfIrO7ykXcuedSq10jt5jsIVj28sdVqebHpK7SArpmpGegSh3TSkNUjzERxd4RKJp6onzys8MA',
#  'results': [{'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 40.4682583, 'lng': -3.6855457},
#     'viewport': {'northeast': {'lat': 40.46961552989271,
#       'lng': -3.684137020107278},
#      'southwest': {'lat': 40.46691587010726, 'lng': -3.686836679892722}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'icon_background_color': '#4B96F3',
# ...

# %%
places = []

# %%
test = g_func.google_places(data, place, places)

# %%
pd_test = pd.DataFrame(test)

# %%
pd_test
# Out:
#                                           name   place_type   latitude  \
# 0                            Carrefour Express  supermarket  40.468258
# 1                        ALIMENTACION GABRIELA  supermarket  40.465771
# 2                       SuperSol supermercados  supermarket  40.462187
# 3                                   Mi Alcampo  supermarket  40.471352
# 4                                          DIA  supermarket  40.469817
# 5                                         Maxi  supermarket  40.465079
# 6                              Supercor Exprés  supermarket  40.463108
# 7                                    Mercadona  supermarket  40.471034
# 8                                        UDACO  supermarket  40.469775
# 9                      ALIMENTACION RIANA S.L.  supermarket  40.470720
# 10                           Gama supermercado  supermarket  40.468038
# 11                          Supermercado Udaco  supermarket  40.471497
# ...

# %%
data_test = g_func.get_restaurants(lat, lon)

# %%
new_places = []
place = "restaurant"

df_test = g_func.google_places(data_test, place, new_places)

# %%
last_df = pd.DataFrame(df_test)

# %%
last_df
# Out:
#                                        name  place_type   latitude  longitude
# 0                   ASADOR EL MOLINO MADRID  restaurant  40.465927  -3.692136
# 1                              Casa Nemesio  restaurant  40.472292  -3.687055
# 2                       El Asador de Aranda  restaurant  40.466376  -3.690591
# 3                                   Rodilla  restaurant  40.467523  -3.689567
# 4                    Pato Laqueado De Pekín  restaurant  40.468033  -3.689720
# 5                                   Asia Té  restaurant  40.471041  -3.685100
# 6              Restaurante Asador Casa Juan  restaurant  40.464026  -3.693268
# 7                Restaurante La Tagliatella  restaurant  40.463356  -3.691760
# 8                   Restaurante L'abbraccio  restaurant  40.463413  -3.692555
# 9                                Espacio 33  restaurant  40.479086  -3.686862
# 10                     Los Arroces de Segis  restaurant  40.463944  -3.693417
# ...
